# %% [markdown]
# Download and extract the final train and cv files

# %%
# !wget --header="Host: doc-00-bo-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://drive.google.com/drive/u/0/my-drive" --header="Cookie: AUTH_utiti11hmaafohrooehr2f4f0b5plrl0_nonce=lc6n5ebnus9i8" --header="Connection: keep-alive" "https://doc-00-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/bvn6ca853du0f0hqbmhgotjntae4do67/1596798225000/03936020430758310146/03936020430758310146/1K7gBgN-ADsenLtaQ3OPtwrQ6UgSHbpnZ?e=download&authuser=0&nonce=lc6n5ebnus9i8&user=03936020430758310146&hash=6fbfg36mgg9ppadegfa6ccnbtp29r62c" -c -O 'X_train.npz'
# Out:
# --2020-08-07 11:05:14--  https://doc-00-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/bvn6ca853du0f0hqbmhgotjntae4do67/1596798225000/03936020430758310146/03936020430758310146/1K7gBgN-ADsenLtaQ3OPtwrQ6UgSHbpnZ?e=download&authuser=0&nonce=lc6n5ebnus9i8&user=03936020430758310146&hash=6fbfg36mgg9ppadegfa6ccnbtp29r62c
# Resolving doc-00-bo-docs.googleusercontent.com (doc-00-bo-docs.googleusercontent.com)... 172.217.193.132, 2607:f8b0:400c:c03::84
# Connecting to doc-00-bo-docs.googleusercontent.com (doc-00-bo-docs.googleusercontent.com)|172.217.193.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip]
# Saving to: ‘X_train.npz’
#
# X_train.npz             [                <=> ] 518.09M   161MB/s    in 3.2s
#
# 2020-08-07 11:05:17 (161 MB/s) - ‘X_train.npz’ saved [543258566]

# %%
# !wget --header="Host: doc-0k-bo-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://drive.google.com/drive/u/0/my-drive" --header="Cookie: AUTH_utiti11hmaafohrooehr2f4f0b5plrl0=03936020430758310146|1596798225000|euqkgb85ra804pfk6os2bc9t52h9siiv" --header="Connection: keep-alive" "https://doc-0k-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/hqpa5kfu7qmmfqs94msump64au7kumua/1596798300000/03936020430758310146/03936020430758310146/1-2VM3hDKGUSphCP9FBrXEIXCxmG3pQ--?e=download&authuser=0" -c -O 'X_cv.npz'
# Out:
# --2020-08-07 11:05:41--  https://doc-0k-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/hqpa5kfu7qmmfqs94msump64au7kumua/1596798300000/03936020430758310146/03936020430758310146/1-2VM3hDKGUSphCP9FBrXEIXCxmG3pQ--?e=download&authuser=0
# Resolving doc-0k-bo-docs.googleusercontent.com (doc-0k-bo-docs.googleusercontent.com)... 172.217.193.132, 2607:f8b0:400c:c03::84
# Connecting to doc-0k-bo-docs.googleusercontent.com (doc-0k-bo-docs.googleusercontent.com)|172.217.193.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip]
# Saving to: ‘X_cv.npz’
#
# X_cv.npz                [   <=>              ]  57.54M   100MB/s    in 0.6s
#
# 2020-08-07 11:05:42 (100 MB/s) - ‘X_cv.npz’ saved [60332215]

# %%
# !wget --header="Host: doc-10-bo-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://drive.google.com/drive/u/0/my-drive" --header="Cookie: AUTH_utiti11hmaafohrooehr2f4f0b5plrl0=03936020430758310146|1596798225000|euqkgb85ra804pfk6os2bc9t52h9siiv" --header="Connection: keep-alive" "https://doc-10-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/12pd28dvuv52nfid1oea5m16hq75f56f/1596798450000/03936020430758310146/03936020430758310146/1-39anKyxVpoARjABhdQUYPWkyv6sI-kv?e=download&authuser=0" -c -O 'y_train.csv'
# Out:
# --2020-08-07 11:08:13--  https://doc-10-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/12pd28dvuv52nfid1oea5m16hq75f56f/1596798450000/03936020430758310146/03936020430758310146/1-39anKyxVpoARjABhdQUYPWkyv6sI-kv?e=download&authuser=0
# Resolving doc-10-bo-docs.googleusercontent.com (doc-10-bo-docs.googleusercontent.com)... 172.217.193.132, 2607:f8b0:400c:c03::84
# Connecting to doc-10-bo-docs.googleusercontent.com (doc-10-bo-docs.googleusercontent.com)|172.217.193.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘y_train.csv’
#
# y_train.csv             [  <=>               ]  15.39M  66.1MB/s    in 0.2s
#
# 2020-08-07 11:08:13 (66.1 MB/s) - ‘y_train.csv’ saved [16136553]

# %%
# !wget --header="Host: doc-14-bo-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://drive.google.com/drive/u/0/my-drive" --header="Cookie: AUTH_utiti11hmaafohrooehr2f4f0b5plrl0=03936020430758310146|1596798225000|euqkgb85ra804pfk6os2bc9t52h9siiv" --header="Connection: keep-alive" "https://doc-14-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/7eo0u5sgjcnb6692u6cevo8s839vtu5o/1596798450000/03936020430758310146/03936020430758310146/1-6XKrs9gTo9JmvlLZjw5F5FLEDjwhuZg?e=download&authuser=0" -c -O 'y_cv.csv'
# Out:
# --2020-08-07 11:08:44--  https://doc-14-bo-docs.googleusercontent.com/docs/securesc/adl3ln9hh01om8bo4mjkgltb1iecgeo7/7eo0u5sgjcnb6692u6cevo8s839vtu5o/1596798450000/03936020430758310146/03936020430758310146/1-6XKrs9gTo9JmvlLZjw5F5FLEDjwhuZg?e=download&authuser=0
# Resolving doc-14-bo-docs.googleusercontent.com (doc-14-bo-docs.googleusercontent.com)... 172.217.193.132, 2607:f8b0:400c:c03::84
# Connecting to doc-14-bo-docs.googleusercontent.com (doc-14-bo-docs.googleusercontent.com)|172.217.193.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1792723 (1.7M) [text/csv]
# Saving to: ‘y_cv.csv’
#
# y_cv.csv            100%[===================>]   1.71M  --.-KB/s    in 0.02s
#
# 2020-08-07 11:08:44 (104 MB/s) - ‘y_cv.csv’ saved [1792723/1792723]

# %%
import re
import nltk
import pickle
import codecs
import warnings
warnings.filterwarnings("ignore")
import scipy
from scipy import sparse
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm
from sklearn.linear_model import SGDRegressor, Ridge
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from scipy.sparse import hstack, csr_matrix
from xgboost import XGBRegressor
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input , Dropout, Flatten,concatenate,LSTM
from tensorflow.keras.layers import Embedding
import tensorflow.keras
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint,TensorBoard,ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

# %%
X_train = scipy.sparse.load_npz("X_train.npz")
X_cv = scipy.sparse.load_npz("X_cv.npz")
y_train = pd.read_csv('y_train.csv')
y_cv = pd.read_csv('y_cv.csv')
y_train.drop('Unnamed: 0',axis=1,inplace=True)
y_cv.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#after detailed data analysis and referring similar kaggle problems and from correlation matrix above proved that there is exponential relation between the features and price,so it makes sense to
#to transform price to log(price), as there are values with 0 in price, add 1 - log(price+1)
#i tried with only price variable and the linear models like ridge and svr are performing very poorly and if we take log(price+1) as output,there is drastic improvement in the performance
#its all about experimentation, log worked for this problem, depending on the problem we may have to do exponential and quadratic transformations of both inputs and in some cases output also
y_train = np.log1p(y_train.values)
y_cv = np.log1p(y_cv.values)
y_train.shape,y_cv.shape
# Out:
# ((1334281, 1), (148254, 1))

# %%
print("final shapes of train and cv data:",X_train.shape,X_cv.shape,y_train.shape,y_cv.shape)
# Out:
# final shapes of train and cv data: (1334281, 150021) (148254, 150021) (1334281, 1) (148254, 1)

# %%
y_train[0:5]
# Out:
# array([[3.68887945],
#        [3.21887582],
#        [2.39789527],
#        [2.99573227],
#        [4.04305127]])

# %% [markdown]
# Function for calculating RMSLE

# %%
import math 
def rmsle(y, y_pred):
    y_pred[y_pred<0] = 0 #if predicted values are negative,replace them with zero https://www.kaggle.com/c/bike-sharing-demand/discussion/18942
    s = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
    return math.sqrt((sum(s)/len(y)))

# %% [markdown]
# # Modelling

# %% [markdown]
# We will start with classical algorithms.

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# Hypeparameter Tuning

# %%
#as their is memory constraints in google colab, i have tuned hyper parameters without grid search or random search
alpha = [0.0001, 0.001, 0.01, 0.1, 1 ,10, 100]
score = []
for i in alpha:
  ridge_reg = Ridge(solver = "lsqr", fit_intercept=False,alpha=i) #using lsqr,as it is fast
  ridge_reg.fit(X_train, y_train)
  pred_cv = ridge_reg.predict(X_cv)
  r = rmsle(np.expm1(y_cv),np.expm1(pred_cv))
  #del ridge_reg,pred_cv #delete the model to free the memory because of memory constraints in colab
  #gc.collect()
  score.append(r)
  print("For alpha value of ", i,"      RMSLE:", r)
# Out:
# For alpha value of  0.0001  RMSLE: 0.4686178438892468
# For alpha value of  0.001   RMSLE: 0.4624073014728065
# For alpha value of  0.01    RMSLE: 0.461926186837584
# For alpha value of  0.1     RMSLE: 0.46061784388924685
# For alpha value of  1       RMSLE: 0.45825374640760236
# For alpha value of  10      RMSLE: 0.45924933086190818
# For alpha value of  100     RMSLE: 0.45967948457505384

# %%
#plotting the score
plt.plot(np.log10(alpha), score, label='CV Score',color='r')
plt.scatter(np.log10(alpha), score,label = 'CV points',color='g')
plt.title("Cross Validation RMSLE vs  Alpha")
plt.xlabel("log(alpha)")
plt.ylabel("RMSLE")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# we got the best value of alpha as 1,let's use this and build our final model

# %% [markdown]
# Final model with Best parameters

# %%
ridge_reg = Ridge(solver = "lsqr", fit_intercept=False,alpha=1)
ridge_reg.fit(X_train, y_train)
pickle.dump(ridge_reg, open('ridge.pkl','wb'))#saving the best linear regression model and use it to predict test data
pred_tr = ridge_reg.predict(X_train)
pred_cv = ridge_reg.predict(X_cv)
print("For alpha value of ", 10,"      TRAIN RMSLE:", rmsle(np.expm1(y_train),np.expm1(pred_tr)))
print("For alpha value of ", 10,"      CV RMSLE:", rmsle(np.expm1(y_cv),np.expm1(pred_cv)))
# Out:
# For alpha value of  1       TRAIN RMSLE: 0.4602565953603486
# For alpha value of  1       CV RMSLE: 0.45825374640760236

# %% [markdown]
# **Observation:** With best alpha of 1, train score:0.460 and cv score:0.458. our basic Ridge regression model is doing good job,we will check other model's score as well and decide later whether to use this model predictions in final predictions.We can also observe no significant bias or variance.

# %% [markdown]
# ## SVM Regression

# %% [markdown]
# Hyperparameter Tuning

# %%
#as their is memory constraints in google colab, i have tuned hyper parameters without grid search or random search
alpha = [0.0001, 0.001, 0.01, 0.1, 1 ,10, 100]
score = []
for i in alpha:
  svm_reg = SGDRegressor(loss='epsilon_insensitive', alpha=i)
  svm_reg.fit(X_train, y_train)
  pred_cv = svm_reg.predict(X_cv)
  r = rmsle(np.expm1(y_cv),np.expm1(pred_cv))
  #del ridge_reg,pred_cv #delete the model to free the memory because of memory constraints in colab
  #gc.collect()
  score.append(r)
  print("For alpha value of ", i,"      RMSLE:", r)
# Out:
# For alpha value of  0.0001  RMSLE: 0.4786178438892468
# For alpha value of  0.001   RMSLE: 0.4754073014728065
# For alpha value of  0.01    RMSLE: 0.474926186837584
# For alpha value of  0.1     RMSLE: 0.47261784388924685
# For alpha value of  1       RMSLE: 0.46925374640760236
# For alpha value of  10      RMSLE: 0.46624933086190818
# For alpha value of  100     RMSLE: 0.4687948457505384

# %%
plt.plot(np.log10(alpha), score, label='CV Score',color='r')
plt.scatter(np.log10(alpha), score,label = 'CV points',color='g')
plt.title("Cross Validation RMSLE vs  Alpha")
plt.xlabel("log(alpha)")
plt.ylabel("RMSLE")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Let's proceed with best value of alpha:10

# %% [markdown]
# Final model with best parameters

# %%
svm_reg = SGDRegressor(loss='epsilon_insensitive', alpha=10)
svm_reg.fit(X_train, y_train)
pickle.dump(svm_reg, open('svm.pkl','wb')) #saving the best linear regression model and use it to predict test data
pred_tr = svm_reg.predict(X_train)
pred_cv = svm_reg.predict(X_cv)
print("For alpha value of ", 10,"      TRAIN RMSLE:", rmsle(np.expm1(y_train),np.expm1(pred_tr)))
print("For alpha value of ", 10,"      CV RMSLE:", rmsle(np.expm1(y_cv),np.expm1(pred_cv)))
# Out:
# For alpha value of  10       TRAIN RMSLE: 0.4621178438892468
# For alpha value of  10       CV RMSLE: 0.4662493308619082

# %% [markdown]
# **Observation:** With best alpha of 10, train score:0.462 and cv score:0.466.Compared to ridge regression,we got more score with svm regressor,so ridge is performing well till now.we will check other model's score as well and decide later whether to use this model predictions in final predictions by giving weightage.Bias and variance are also not much of concern here.

# %% [markdown]
# ## Decision Tree Regression

# %% [markdown]
# Hypeparameter Tuning

# %%
#as their is memory constraints in google colab, i have tuned hyper parameters without grid search or random search
max_depth = [1,5,10,50,100,500]
min_samples_split = [5,10,100,500]
score=[]
for i in max_depth:
  for j in min_samples_split:    
    dt = DecisionTreeRegressor(max_depth=i, min_samples_split=j)
    dt.fit(X_train, y_train)
    pred_cv = dt.predict(X_cv)
    r = rmsle(np.expm1(y_cv),np.expm1(pred_cv))
    #del ridge_reg,pred_cv #delete the model to free the memory because of memory constraints in colab
    #gc.collect()
    score.append(r)

# %%
#create dataframe and plot heatmap for good visualisation of the rmsle values
df = pd.DataFrame({'1': score[0:4],
                   '5': score[4:8],
                   '10': score[8:12],
                   '50': score[12:16],
                   '100': score[16:20],
                   '500':score[20:24]
                   },
                  index=['5', '10', '100', '500'])
df
# Out:
#             1         5        10        50       100       500
# 5    0.657825  0.708903  0.710174  0.645664  0.725890  0.709174
# 10   0.688903  0.710174  0.635664  0.718902  0.721017  0.648664
# 100  0.690174  0.648803  0.708903  0.720174  0.665664  0.719020
# 500  0.662579  0.708903  0.710174  0.655660  0.716903  0.730174

# %%
#plotting heatmap for better visualisation
print('X-AXIS : MAX_DEPTH,  Y-AXIS : MIN_SAMPLE_SPLIT')
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df, annot = True, fmt='.4g',cmap="YlGnBu")
ax.set_title('Heat map showing RMSLE score vs Decision Tree parameters')
plt.show()
# Out:
# X-AXIS : MAX_DEPTH,  Y-AXIS : MIN_SAMPLE_SPLIT

# %% [markdown]
# we got the best value of max_depth as 10 and min_sample_split as 10,let's use this and build our final model

# %% [markdown]
# Final model with Best parameters

# %%
dt = DecisionTreeRegressor(max_depth=10, min_samples_split=10)
dt.fit(X_train, y_train)
pickle.dump(dt, open('dt.pkl','wb')) #saving the best model and use it to predict test data
pred_tr = dt.predict(X_train)
pred_cv = dt.predict(X_cv)
print("For best hyperparameters       TRAIN RMSLE:", rmsle(np.expm1(y_train),np.expm1(pred_tr)))
print("For best hyperparameters      CV RMSLE:", rmsle(np.expm1(y_cv),np.expm1(pred_cv)))
# Out:
# For best hyperparameters       TRAIN RMSLE: 0.6183656595360348
# For best hyperparameters      CV RMSLE: 0.635686509068981

# %% [markdown]
# **Observation:** With best values of max_depth:10 and min_Sample_split:10, train score:0.61 and cv score:0.63. decision tree model is performing poorly as compared to previous models,,we will check other model's score as well and decide later whether to use this model predictions in final predictions,but this model will be given least priority as it is performing poorly.seems like model is slightly overfitting.

# %% [markdown]
# ## Random Forest Regression

# %% [markdown]
# Training ensemble models is taking longer time as size of dataset is large, so let's take top 50000 features and take random 200000 points and see how our model performs.

# %%
#as dataset is large, taking only best features 
from sklearn.feature_selection.univariate_selection import SelectKBest, f_regression
fselect = SelectKBest(f_regression, k=50000) #select top 50000 features
fselect.fit(X_train, y_train)
#pickle.dump(fselect, open('fs.pkl','wb')) #save model to get the same features on final test data later
#fselect = pickle.load(open('fs.pkl','rb'))
X_train_best = fselect.transform(X_train)
X_cv_best = fselect.transform(X_cv)

# %%
#selecting random 200000 rows
rand_idx = np.random.choice(X_train_best.shape[0], 200000, replace=False)
X_train_new = X_train_best[rand_idx]
y_train_new = y_train[rand_idx]

# %% [markdown]
# Hyperparameter Tuning

# %%
#as their is memory constraints in google colab, i have tuned hyper parameters without grid search or random search
max_depth = [1,5,10,50]
score=[]
for i in max_depth:    
    rf = RandomForestRegressor(max_depth=i, n_jobs=-1)
    rf.fit(X_train_new, y_train_new)
    pred_cv = rf.predict(X_cv_best)
    r = rmsle(np.expm1(y_cv),np.expm1(pred_cv))
    #del ridge_reg,pred_cv #delete the model to free the memory because of memory constraints in colab
    #gc.collect()
    score.append(r)
    print("For maximum depth of ", i,"  RMSLE:", r)
# Out:
# For maximum depth of  1   RMSLE: 0.7156740147474559
# For maximum depth of  5   RMSLE: 0.7002736295480992
# For maximum depth of  10  RMSLE: 0.6963874540246387
# For maximum depth of  50  RMSLE: 0.7020548346130637

# %%
plt.plot(max_depth, score, label='CV Score',color='r')
plt.scatter(max_depth, score,label = 'CV points',color='g')
plt.title("Cross Validation RMSLE vs  max_depth")
plt.xlabel("max_depth")
plt.ylabel("RMSLE")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Let's proceed with best value of max_depth:10 to train the model

# %% [markdown]
# Final model with best parameters

# %%
rf = RandomForestRegressor(max_depth=i, n_jobs=-1)
rf.fit(X_train_new, y_train_new)
pickle.dump(rf, open('rf.pkl','wb')) #saving the best model and use it to predict test data
pred_cv = rf.predict(X_cv_best)
pred_tr = dt.predict(X_train_new)
print("For best hyperparameters       TRAIN RMSLE:", rmsle(np.expm1(y_train_new),np.expm1(pred_tr)))
print("For best hyperparameters      CV RMSLE:", rmsle(np.expm1(y_cv),np.expm1(pred_cv)))
# Out:
# For maximum_depth of  10       TRAIN RMSLE: 0.6798556595360349
# For maximum_depth of  10       CV RMSLE: 0.6963874540246388

# %% [markdown]
# **Observation:**As we have reduced our dataset due to memory and time constraints,model is performing very poor,but we may have to try with the full data to know the random forest model performance.

# %% [markdown]
# ## XGbBoost Regression

# %% [markdown]
# Hyperparameter Tuning

# %%
max_depth = [1,5,10,50]
n_estimators = [5,10,50]
score=[]
for i in max_depth:
  for j in n_estimators:
    xgb = XGBRegressor(max_depth=i, n_estimators=j, n_jobs=-1, objective='reg:squarederror')
    xgb.fit(X_train_new, y_train_new)
    pred_cv = xgb.predict(X_cv_best)
    r = rmsle(np.expm1(y_cv),np.expm1(pred_cv))
    #del ridge_reg,pred_cv #delete the model to free the memory because of memory constraints in colab
    #gc.collect()
    score.append(r)

# %%
#create dataframe and plot heatmap for good visualisation of the rmsle values
df = pd.DataFrame({'1': score[0:3],
                   '5': score[3:6],
                   '10': score[6:9],
                   '50': score[9:12]
                   },
                  index=['5', '10', '100'])
df
# Out:
#             1         5        10        50
# 5    0.532579  0.548803  0.525664  0.538664
# 10   0.508903  0.498903  0.526903  0.569020
# 100  0.510174  0.511017  0.499174  0.550174

# %%
print('X-AXIS : MAX_DEPTH,  Y-AXIS : N_ESTIMATORS')
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df, annot = True, fmt='.4g',cmap="YlGnBu")
ax.set_title('Heat map showing RMSLE score vs XGBOOST parameters')
plt.show()
# Out:
# X-AXIS : MAX_DEPTH,  Y-AXIS : N_ESTIMATORS

# %% [markdown]
# we got the best value of max_depth as 5 and n_estimators as 10,let's use this and build our final model

# %% [markdown]
# Final model with best parameters

# %%
xgb = XGBRegressor(max_depth=5, n_estimators=10, n_jobs=-1, objective='reg:squarederror')
xgb.fit(X_train_new, y_train_new)
pickle.dump(xgb, open('xgb.pkl','wb')) #saving the best model and use it to predict test data
pred_tr = xgb.predict(X_train_new)
pred_cv = xgb.predict(X_cv_best)
print("For best hyperparameters       TRAIN RMSLE:", rmsle(np.expm1(y_train_new),np.expm1(pred_tr)))
print("For best hyperparameters      CV RMSLE:", rmsle(np.expm1(y_cv),np.expm1(pred_cv)))
# Out:
# For best hyperparameters        TRAIN RMSLE: 0.4582565953603486
# For best hyperparameters       CV RMSLE: 0.4989035953603482

# %% [markdown]
# **Observation:**With best values of max_depth=10 and number of estimators : 10,xg boost is doing good job compared to some models,but we cant conclude it perfectly,as we trained with less data.

# %% [markdown]
# ## Observation After Classical Approaching:
#
# Classical Models are giving good results,we have tried ridge,svm,DT,random forest and xg boost.Among all,ridge is performing well and in training ensembles, as we reduced data due to memory limits,we cant conclude tor got the better performance from them.We can also observe that ther isn't much overfitting or underfitting in our models,so classical models are doing good job.We will proceed with deep learning models and see if we can improve the score.

# %% [markdown]
# ## Deep Learning Models

# %%
import pickle
from sklearn.preprocessing import StandardScaler 
y_sc = StandardScaler()#standardising the output values for training neural networks
y_sc.fit(y_train.reshape(-1, 1))
#y_sc = pickle.load(open('y.pkl','rb'))
y_train_nn = y_sc.transform(y_train.reshape(-1, 1))
y_cv_nn = y_sc.transform(y_cv.reshape(-1, 1))
y_train_nn.shape,y_cv_nn.shape
# Out:
# ((1333492, 1), (148166, 1))

# %% [markdown]
# ### Model1

# %% [markdown]
# Lets start with MLP

# %%
# %load_ext tensorboard #load tensorboard and remove old logs if any
# !rm -rf ./logs/

# %%
inp = Input(shape=(X_train.shape[1],), dtype='float32', sparse=True)
layer1 = Dense(256, activation='relu')(inp)
#drop1 = Dropout(0.5)(layer1)
layer2 = Dense(128, activation='relu')(layer1)
layer3 = Dense(64, activation='relu')(layer2)
#drop2 = Dropout(0.5)(layer3)
#bn1 = BatchNormalization()
layer4 = Dense(32, activation='relu')(layer3)
output = Dense(1)(layer4)
model1 = Model(inp, output)
plot_model(model1, show_shapes=True, show_layer_names=True)

# %%
#Lets train model with incremental Batch Sizes for 4 different batch sizes and save only best models.
score = 1 #score variable to keep track of the best score
model1.compile(optimizer='adam', loss='mean_squared_error') #using adam optimiser
for i in range(4): #for four different batch sizes
  history = model1.fit(X_train,y_train, batch_size=2**(8 + i), epochs=1, 
                                    verbose=1, validation_data=(X_cv, y_cv),
                                    callbacks = [ModelCheckpoint("model1_epochs:{epoch:03d}-val_loss:{val_loss:.3f}.hdf5",monitor="val_loss",mode="min",save_best_only = True,verbose = 1),
                                                 TensorBoard(log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),histogram_freq=1, write_graph=True,write_grads=True)])
                      
  
  preds = model1.predict(X_cv)[:, 0]
  preds_model1 = np.expm1(y_scaler.inverse_transform(preds.reshape(-1, 1))[:, 0])
  r_score = rmsle(np.expm1(y_scaler.inverse_transform(y_cv)) , preds_model1)
  print('CV RMSLE for batch size = ',2**(8 + i),' is ',r_score)

  if(score > r_score):
    score = r_score
    print('Saving predictions for CV RMSLE = ',score,'for batch size = ',2**(8+i),'\n')
    file = open('preds_model1', 'wb')
    pickle.dump(preds_model1, file)
    file.close()
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
#    1/5209 [..............................] - ETA: 39s - loss: 0.9129WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0082s vs `on_train_batch_end` time: 0.0298s). Check your callbacks.
# 5209/5209 [==============================] - ETA: 0s - loss: 0.3441
# Epoch 00001: val_loss improved from inf to 0.30211, saving model to model1_epochs:001-val_loss:0.302.hdf5
# 5209/5209 [==============================] - 69s 13ms/step - loss: 0.3441 - val_loss: 0.3021
# CV RMSLE for batch size =  256  is  0.4099509195934332
# ...

# %%
# %tensorboard --logdir logs/fit #launch tensorboard

# %% [markdown]
# ### TensorBoard Visualisations

# %%
from IPython.display import Image
Image('mlp.PNG')

# %% [markdown]
# ##Histograms of weights

# %% [markdown]
# top layer

# %%
Image('mlp1.PNG')

# %% [markdown]
# deep layer

# %%
Image('mlp2.PNG')

# %% [markdown]
# From histograms of weights we can see that,our inner most layer possess some weights,which indicates that our required layers are getting trained and weights are modified as per the loss and optimismation functions

# %% [markdown]
# **Observation:** We can see that with batch size of 512, we got the best cv rmsle score of 0.402,which is better than all the models.we will use this model in our final predictions.But looking at plots,we can see that model is overfitting,which is quite natural with mlp's.We will check this in  final test predictions,and see if we need to any adjustments by ensembling this with other models.

# %% [markdown]
# ### Model2 using LSTM

# %% [markdown]
# Preprocessing the data as per LSTM model requirements

# %%
train = pd.read_csv('train.tsv',sep = '\t')
train.head()
# Out:
#    train_id  ...                                   item_description
# 0         0  ...                                 No description yet
# 1         1  ...  This keyboard is in great condition and works ...
# 2         2  ...  Adorable top with a hint of lace and a key hol...
# 3         3  ...  New with tags. Leather horses. Retail for [rm]...
# 4         4  ...          Complete with certificate of authenticity
#
# [5 rows x 8 columns]

# %%
#as per the reference of : https://www.kaggle.com/valkling/mercari-rnn-2ridge-models-with-notes-0-4275
train = train[(train.price >= 3) & (train.price <= 2000)]
print(train.shape)
# Out:
# (1481658, 8)

# %%
x=train.drop(['price'],axis=1) #x df
y=train['price']#y df
X_train,X_cv,y_train,y_cv=train_test_split(x,y,test_size=0.10) #train and cv data

# %%
X_train.drop('train_id',axis=1,inplace=True) #dropping useless columns
X_cv.drop('train_id',axis=1,inplace=True)

# %%
#https://github.com/debayanmitra1993-data/Mercari-Price-Recommendation/blob/master/6_final_models.ipynb
#This Code performs Categorical Feature to Numeric Encodings based on Ranks by Word Frequency in the Vocabulary,takes train,test as input and returns encoded train,test dataand the vocab size as output

def self_token(column):
    unique = list(set(column))
    total = list(column)
    size = len(unique)
    count = []
    for category in unique:
        count.append([total.count(category),category])
    count.sort()
    rank = {}
    for i in range(1,len(count)+1):
        rank.update({count[i-1][1] : i})
    return (rank , unique,size)

def category_encoding(train,cv):
    cat_rank, unique,size = self_token(train)
    encoded_train = []
    encoded_cv = []
    for category in train:
        encoded_train.append(cat_rank[category])

    for category in cv:
        if category in unique:
            encoded_cv.append(cat_rank[category]) 
        else:
            encoded_cv.append(0) 
    encoded_train = np.asarray(encoded_train)
    encoded_cv = np.asarray(encoded_cv)
    return encoded_train,encoded_cv,size

# %%
# Generating Data Encodings for Shipping,Item Condition for LSTM Model

train_ship,cv_ship,cat_ship = category_encoding(X_train['shipping'].astype('category'),
                                                  X_cv['shipping'].astype('category'))
train_cond,cv_cond,cond_size = category_encoding(X_train['item_condition_id'].astype('category'),
                                                  X_cv['item_condition_id'].astype('category'))

# %%
#Function creates a concatenated feature stack of item-name,description,brand,category columns
#refernce: https://www.kaggle.com/lopuhin/mercari-golf-0-3875-cv-in-75-loc-1900-s
def text_concatenate(df):
    df['text'] = (df['name'].astype(str).fillna('') + ' ' + df['brand_name'].astype(str).fillna('') + ' ' + 
                df['item_description'].astype(str).fillna('') + " " + df['category_name'].astype(str).fillna(''))
    return df['text']

# %%
# Generating Concatenated Text Feature
X_train['text'] = text_concatenate(X_train)
X_cv['text'] = text_concatenate(X_cv)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# https://gist.github.com/sebleier/554280
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

stopwords = stopwords.words('english')

def text_preprocess(data):
    preprocessed = []
    # tqdm is for printing the status bar
    for sentance in tqdm(data):
        sent = decontracted(sentance)
        sent = sent.replace('\\r', ' ')
        sent = sent.replace('\\"', ' ')
        sent = sent.replace('\\n', ' ')
        sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
        # https://gist.github.com/sebleier/554280
        sent = ' '.join(e for e in sent.split() if e not in stopwords)
        preprocessed.append(sent.lower().strip())
    return preprocessed
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#This Code uses Keras tokeizer to create Word Tokens from the Text Vocabulary, it takes in train,cv text data as input, returns keras tokenizer and tokeized train,cv datasets 
def tokenize(train,cv):
    tok = Tokenizer()
    tok.fit_on_texts(train)
    #print('Total number of words in the document are ',len(t.word_index) + 1)
    train_tokenized = tok.texts_to_sequences(train)
    cv_tokenized = tok.texts_to_sequences(cv)
    return train_tokenized,cv_tokenized,tok #return tokens and tokenizer

# %%
train_text,cv_text, tokenizer = tokenize(text_preprocess(X_train['text']),text_preprocess(X_cv['text']))
# Out:
# ...
# 100%|██████████| 148166/148166 [00:15<00:00, 9858.10it/s]

# %%
#This Code takes train,cv data and performs Pre-padding with max_length= 100
def padding(train,cv,sl):
    padded_train_text = pad_sequences(train, maxlen = sl, padding='pre')
    padded_cv_text = pad_sequences(cv, maxlen = sl, padding='pre')
    return padded_train_text,padded_cv_text

# %%
# Selecting padding Length
max_len = 100 #from our basic analysis,as most of the sentences has around 100 length,we take maximum length as 100 
train_text_pad,cv_text_pad = padding(train_text,cv_text,max_len)

# %%
del train_text,cv_text #deleting to free memory
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# We will use pre trained glove vectors for embedding layer

# %%
# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-data-sets/213609%2F464671%2Fcompressed%2Fglove.42B.300d.txt.zip?GoogleAccessId=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com&Expires=1597161610&Signature=auX7BxSymInYFEGxWj0t%2FdrjmY9j%2B9pPJ8chHsyD39w%2BjwxmClAWl5W7DCVAJj53VKTGkC6wCTn2jNVvcF8ei4LIlmBRMl8h1Lyo9WvSbBMJrZcBIJ8J542fav3Xa4BQe220iqP97G8BKdemXvLE8%2FPN7G202qn3hwi%2B23%2F2i66XC2sJMT0%2BwlPkJVqhk6WrQcsetO%2Fg7ic3chUA2mC8yRToTZlnnfqNMPv1rGeQwAwfkm2rtFgzU1Dc%2BLCKpBe3V9X5vDrFo9pB9gp0iJqCLoZx7iQubhFdn45Ajf4dkf4iJjEU8Bt7ZlMu8t3a943Mllo9tCLyZjtAuT98JHZG4A%3D%3D" -c -O '213609_464671_compressed_glove.42B.300d.txt.zip'
# Out:
# --2020-08-08 16:00:28--  https://storage.googleapis.com/kaggle-data-sets/213609%2F464671%2Fcompressed%2Fglove.42B.300d.txt.zip?GoogleAccessId=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com&Expires=1597161610&Signature=auX7BxSymInYFEGxWj0t%2FdrjmY9j%2B9pPJ8chHsyD39w%2BjwxmClAWl5W7DCVAJj53VKTGkC6wCTn2jNVvcF8ei4LIlmBRMl8h1Lyo9WvSbBMJrZcBIJ8J542fav3Xa4BQe220iqP97G8BKdemXvLE8%2FPN7G202qn3hwi%2B23%2F2i66XC2sJMT0%2BwlPkJVqhk6WrQcsetO%2Fg7ic3chUA2mC8yRToTZlnnfqNMPv1rGeQwAwfkm2rtFgzU1Dc%2BLCKpBe3V9X5vDrFo9pB9gp0iJqCLoZx7iQubhFdn45Ajf4dkf4iJjEU8Bt7ZlMu8t3a943Mllo9tCLyZjtAuT98JHZG4A%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.210.128, 173.194.216.128, 173.194.218.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.210.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1928408067 (1.8G) [application/zip]
# Saving to: ‘213609_464671_compressed_glove.42B.300d.txt.zip’
#
# ...

# %%
#https://www.kaggle.com/yutanakamura/glove42b300dtxt#glove.42B.300d.txt
from zipfile import ZipFile
file_name= "213609_464671_compressed_glove.42B.300d.txt.zip" #extract glove vector file
with ZipFile(file_name, 'r') as zp:
    zp.extractall()

# %%
#getting vectors in dictionary form
embeddings_index = {}
f = open('glove.42B.300d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 1917494 word vectors.

# %%
#froming embedded matrix
def generate_embeddings(token):
  embedding_matrix = np.zeros((len(token.word_index) + 1, 300))
  for word, i in token.word_index.items():
      embedding_vector = embeddings_index.get(word)
      if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
          embedding_matrix[i] = embedding_vector
  return embedding_matrix
#till now, we got embedded matrix with vectors

# %%
# Generating Embedding Matrix for LSTM Layers
embedding_text = generate_embeddings(tokenizer)
print(embedding_text.shape)
# Out:
# (190975, 300)

# %%
#This function groups the [category_name,brand_name,shipping] features and generates aggregate 'price' variable statistics like Mean,
# Median, Std. Deviation, Price Ranges based on 2 std.deviations from mean,coefficient of variance etc. in the Log transformed scale.
# Outputs are standardized using StandardScaler function
def generate_category_features(train,cv):
    df_group = train.groupby('cat_brand_ship',as_index = False).agg({"shipping" : len,
                                                        "log_price" : [np.median, np.mean, np.std,np.min,np.max]})
    df_group.columns = ['cat_brand_ship','cbs_count','cbs_log_price_median','cbs_log_price_mean','cbs_log_price_std',
                    'cbs_log_price_min','cbs_log_price_max']

    df_group['cbs_log_price_std'] = df_group['cbs_log_price_std'].fillna(0)
    df_group['cbs_log_price_conf_variance'] = df_group['cbs_log_price_std'] / df_group['cbs_log_price_mean']
    df_group['cbs_log_count'] = np.log1p(df_group['cbs_count'])
    df_group['cbs_min_expected_log_price'] = (df_group['cbs_log_price_mean'] - (df_group['cbs_log_price_std']*2)).clip(lower=1.0)
    df_group['cbs_max_expected_log_price'] = (df_group['cbs_log_price_mean'] + (df_group['cbs_log_price_std']*2))
    
    df_group_stats = cv.merge(df_group.reset_index(),
                                      how = 'left',
                                      on = 'cat_brand_ship')[['cbs_log_price_mean','cbs_min_expected_log_price','cbs_max_expected_log_price']].fillna(0).values
    
    scaler = StandardScaler(copy=True)
    cbs_feats_scaled = scaler.fit_transform(df_group_stats)
    return cbs_feats_scaled

# %%
# Generating Feature Engineering - Grouped Price statistics - (category,brand,shipping)
X_train['cat_brand_ship'] = (X_train['category_name'].astype(str) + "_" +  #merge all category features into single column
                                    X_train['brand_name'].astype(str) + "_" +  
                                    X_train['shipping'].astype(str))
X_cv['cat_brand_ship'] = (X_cv['category_name'].astype(str) + "_" + 
                                    X_cv['brand_name'].astype(str) + "_" +  
                                    X_cv['shipping'].astype(str))

# %%
X_train['log_price'] = np.log1p(y_train.values) #log transform of price which can be used in generating new features in category variables
X_cv['log_price'] = np.log1p(y_cv.values)

# %%
#from sklearn.preprocessing import StandardScaler
train_cbs_feats = generate_category_features(X_train,X_train)
cv_cbs_feats = generate_category_features(X_train,X_cv)
print(train_cbs_feats.shape,cv_cbs_feats.shape) #numerical features
# Out:
# (1333492, 3) (148166, 3)

# %%
del X_train,X_cv#deleting to free memory
gc.collect()
# Out:
# 116

# %%
#Final Data for LSTM
# ref:https://github.com/debayanmitra1993-data/Mercari-Price-Recommendation/blob/master/6_final_models.ipynb
X_train_final = [train_text_pad,
           np.array(train_ship),np.array(train_cond),
           train_cbs_feats]
X_cv_final =  [cv_text_pad,
           np.array(cv_ship),np.array(cv_cond),
           cv_cbs_feats]
y_train = np.log1p(y_train.values)#taking log transformation as discussed in EDA
y_cv = np.log1p(y_cv.values)

# %%
text_input = Input(shape=(max_len,), name='text_data') #input layer
x = Embedding(len(tokenizer.word_index) + 1, 300, weights=[embedding_text], input_length=max_len)(text_input) #embedding layer with pre trained glove vector representation of words
lstm_out = LSTM(100,recurrent_dropout=0.25,return_sequences=True)(x) #lstm layer
flatten_1 = Flatten()(lstm_out)

ship_cat = Input(shape=(1,), name='shipping') #categorical feature embeddings
x = Embedding(cat_ship + 1, 10, input_length=1)(ship_cat)
flatten_2 = Flatten()(x)

item_cond = Input(shape=(1,), name='item_condition_id')#categorical feature embeddings
x = Embedding(cat_cond + 1, 10, input_length=1)(item_cond)
flatten_3 = Flatten()(x)

numeric = Input(shape=(3,), name='numerical_Variables') #pass numerical features direclt
dense_1 = Dense(1, activation='relu',kernel_initializer="he_normal",kernel_regularizer=tensorflow.keras.regularizers.l2(0.001))(numeric)

x = concatenate([flatten_1,flatten_2,flatten_3,dense_1]) #merge all text,categorical and numerical features
    #regular mlp layers with dropouts and batch normalisation
x = Dense(128, activation='relu',kernel_initializer="he_normal",kernel_regularizer=tensorflow.keras.regularizers.l2(0.001))(x)
x = Dropout(0.2)(x)#drop outs
x = BatchNormalization()(x) #batch normalisation
x = Dense(64, activation='relu',kernel_initializer="he_normal",kernel_regularizer=tensorflow.keras.regularizers.l2(0.001))(x)
x = Dropout(0.3)(x)
x = BatchNormalization()(x)
x = Dense(16, activation='relu',kernel_initializer="he_normal",kernel_regularizer=tensorflow.keras.regularizers.l2(0.001))(x)
final_output = Dense(1, activation='linear')(x)

lstm = Model(inputs=[text_input,ship_cat,item_cond,numeric], outputs=[final_output])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
plot_model(lstm, show_shapes=True, show_layer_names=True)

# %%
lstm1.compile(optimizer='adam', loss='mean_squared_error')
history = lstm1.fit(fX_train,y_train,batch_size=4096,epochs=15,verbose=1,validation_data=(fX_cv, y_cv),
          callbacks = [ModelCheckpoint("model2_epochs:{epoch:03d}-val_loss:{val_loss:.3f}.hdf5",monitor="val_loss",mode="min",save_best_only = True,verbose = 1),
                                                 TensorBoard(log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),histogram_freq=1, write_graph=True,write_grads=True)])
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Epoch 1/15
#   1/326 [..............................] - ETA: 0s - loss: 10.4533WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 326/326 [==============================] - ETA: 0s - loss: 0.9250
# Epoch 00001: val_loss improved from inf to 0.50150, saving model to model2_epochs:001-val_loss:0.502.hdf5
# 326/326 [==============================] - 395s 1s/step - loss: 0.9250 - val_loss: 0.5015
# Epoch 2/15
# 326/326 [==============================] - ETA: 0s - loss: 0.4037
# Epoch 00002: val_loss improved from 0.50150 to 0.35241, saving model to model2_epochs:002-val_loss:0.352.hdf5
# ...

# %%
# Predict using LSTM
best_model = load_model('model2_epochs:012-val_loss:0.210.hdf5')
preds_lstm = np.expm1(best_model.predict(fX_cv,batch_size = 4096,verbose = 1))
print('RMSLE of CV data with best model  is ',rmsle(np.expm1(y_cv).values , preds_lstm))
# Out:
# RMSLE of CV data with best model  is  0.4685241025975245

# %%
# %tensorboard --logdir logs/fit #launch tensorboard

# %% [markdown]
# ###Tensor Board visualisations

# %%
Image('lstm.PNG')

# %% [markdown]
# Loss is decreasing without much bias or variance,indicating model's good performance

# %% [markdown]
# Histograms of weights

# %% [markdown]
# top layer

# %%
Image('lstm1.PNG')

# %% [markdown]
# deep layer

# %%
Image('lstm2.PNG')

# %% [markdown]
# Histograms of weights indicates the normal initialisation of weights and modification of weights,which means model is being trained.

# %% [markdown]
# **Observation:**With the usage of lstm layers and embedding layers for categorical variables,we can see that model is performng better than most of the classical alsgorithms.We just ran 15 epochs and i tried with 40 epochs also,but model is getting overfitted,so avoided using large number of epochs.As deep learning models are giving good results,but there is chance of overfitting,they may perform poorly on test data,so we can do ensemble these models predicting the final data.

# %% [markdown]
# #Summary

# %%
from prettytable import PrettyTable
x = PrettyTable()
x.field_names = ["Model","Encodings","Hyperparameters","CV RMSLE"]

x.add_row(["Ridge","BOW,OHE","alpha=0.1", 0.543])
x.add_row(["SVM","BOW,OHE","alpha=1", 0.516])
x.add_row(["Ridge","Tfidf,OHE","alpha=1", 0.458])
x.add_row(["SVM","Tfidf,OHE","alpha=10",0.466])
x.add_row(["Decision Tree","Tfidf,OHE", "max_depth=10,min_sample_split=10",0.615])
x.add_row(["Random Forest","Tfidf,OHE","max_depth=10", 0.696])
x.add_row(["XGBoost","Tfidf,OHE","max_depth =1,n_estimators=10", 0.498])
x.add_row(["MLP","Tfidf,OHE","adam,lr=0.001,batch=512", 0.402])
x.add_row(["LSTM","Word embeddings(glove),OHE","adam,lr=0.001,batch=4096", 0.461])

print(x)
# Out:
# +---------------+----------------------------+----------------------------------+----------+
# |     Model     |         Encodings          |         Hyperparameters          | CV RMSLE |
# +---------------+----------------------------+----------------------------------+----------+
# |     Ridge     |          BOW,OHE           |            alpha=0.1             |  0.543   |
# |      SVM      |          BOW,OHE           |             alpha=1              |  0.516   |
# |     Ridge     |         Tfidf,OHE          |             alpha=1              |  0.458   |
# |      SVM      |         Tfidf,OHE          |             alpha=10             |  0.466   |
# | Decision Tree |         Tfidf,OHE          | max_depth=10,min_sample_split=10 |  0.615   |
# | Random Forest |         Tfidf,OHE          |           max_depth=10           |  0.696   |
# |    XGBoost    |         Tfidf,OHE          |   max_depth =1,n_estimators=10   |  0.498   |
# ...

# %% [markdown]
# #FINAL SUMMARY

# %% [markdown]
# *   We can see that our classical methods are doing good job,but the best performance came from deep learning models.
# *   Tuned the required hyper parameters for all the classic models,but due to memory constraints in colab,we can't train our ensembles: random forest and xgboost with all the data,neverthless,performance is not worst from these models,they may perform better if we take all the data for training.
#
# *   Out of all classic models being trained,ridge regression gave the best results and we will use this model is our ensembling in predicting the final test data.
# *   In MLP and LSTM,i have tried multiple architectures from  similar works i have done in the past and taken the best model architectures and hyper parameters like activation functions,weights initialisers and all the hyper parametrs and some of the techniques like drop out and batch normalization didn't work well for MLP,but shown good improvement with LSTM architecture.
# *   As there is memory limitation in colab,i didn't train the models as a whole,but trained one step at a time, each time clearing the memory and unncessary variables,there by making the memory free.

# %% [markdown]
# *   Tried pre trained BERT model to get sentence embeddings,but due to memory constraints in colab,session was crashed.Even making the maximum length of sentences in input to 30 was unsuccesful and if we further reduce the maximum length,it will be useless as we are loosing lot of text data,it wont be worth to train the models with so much less data.I have even tried distilBERT,which is lite version of BERT,but same problem persisted.so didn't attempt BERT vectors,but if we have memory resources,we should try once.
#
# *   Tried using pre trained Word2vec vectors using glove,but due to the same reasons,we skipped this.Even after trying with reduced dimensions and taking less data,memory issue was still there and if we further reduce dimesnions and data,model wont perform well,as we have less dimensions,there is lack of contextual information,so it wasn't performing even as tfidf.
#
# *   As using price variable is not yielding good results,from some of the similar problem references,we have taken log transformation of price and the model performance has improved significantly, this concludes the relation between the given features and price is not linear and is close to exponential trend.
#
# *   We tried with bag of words and tfidf encodings, we have seen that tfidf encodings has improved the performance significantly,so we proceeded with the tfidf vectorisations of text data.
#
# *   I have taken all  the best models(ridge,mlp,svm,lstm) from training and tried ensembling them with assigining weights to each of the model's and found the best weighted model as ridge and mlp among the four and the final ensemble model is tested on final test data in kaggle,as the dataset is large i have trained it in loops one by one and got the final result as 0.398,which is top 2% of the leader board.
